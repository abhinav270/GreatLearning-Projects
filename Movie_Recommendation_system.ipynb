# %% [markdown]
# <a href="https://colab.research.google.com/github/abhinav270/GreatLearning-Projects/blob/main/Movie_Recommendation_system.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Movie Recommendation System

# %%
# !git clone https://github.com/abhinav270/Movie-Recommendation-System.git
# Out:
# Cloning into 'Movie-Recommendation-System'...
# remote: Enumerating objects: 12, done.
# remote: Counting objects: 100% (12/12), done.
# remote: Compressing objects: 100% (11/11), done.
# remote: Total 12 (delta 1), reused 4 (delta 0), pack-reused 0
# Unpacking objects: 100% (12/12), done.

# %%
cd /content/Movie-Recommendation-System
# Out:
# /content/Movie-Recommendation-System

# %%
import os
import pandas as pd
import numpy as np
os.getcwd()
# Out:
# '/content/Movie-Recommendation-System'

# %%
path = os.path.join(os.getcwd(),'Dataset')

# %%
os.listdir(path)
# Out:
# ['tmdb_5000_credits.csv', 'tmdb_5000_movies.csv']

# %%
credit_df = pd.read_csv(os.path.join(path,'tmdb_5000_credits.csv'))
movies_df = pd.read_csv(os.path.join(path,'tmdb_5000_movies.csv'))

# %%
credit_df.head(10)
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
# 5       559                              Spider-Man 3
# 6     38757                                   Tangled
# 7     99861                   Avengers: Age of Ultron
# 8       767    Harry Potter and the Half-Blood Prince
# 9    209112        Batman v Superman: Dawn of Justice
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2  [{"cast_id": 1, "character": "James Bond", "cr...
# 3  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4  [{"cast_id": 5, "character": "John Carter", "c...
# ...

# %%
movies_df.head(10)
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 5  258000000  [{"id": 14, "name": "Fantasy"}, {"id": 28, "na...
# 6  260000000  [{"id": 16, "name": "Animation"}, {"id": 10751...
# 7  280000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 8  250000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 9  250000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                             homepage      id  \
# 0                        http://www.avatarmovie.com/   19995
# 1       http://disney.go.com/disneypictures/pirates/     285
# 2        http://www.sonypictures.com/movies/spectre/  206647
# ...

# %%
movies_df=pd.merge(movies_df,credit_df,how = 'left',left_on='id',right_on='movie_id')

# %%
movies_df
# Out:
#          budget                                             genres  \
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2     245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3     250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4     260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...         ...                                                ...
# 4798     220000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4799       9000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 4800          0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 4801          0                                                 []
# 4802          0                [{"id": 99, "name": "Documentary"}]
#
#                                                homepage      id  \
# 0                           http://www.avatarmovie.com/   19995
# ...

# %%
gen_dic = movies_df.genres[0]

# %%
gen_dic
# Out:
# '[{"id": 28, "name": "Action"}, {"id": 12, "name": "Adventure"}, {"id": 14, "name": "Fantasy"}, {"id": 878, "name": "Science Fiction"}]'

# %%
def GenreList(text:str)->list:
  list_genre = []
  for i in list(eval(text)):
    for key,item in i.items():
      if key=='name':
        list_genre.append(item)
  return sorted(list(set(list_genre)))

# %%
movies_df.genres = movies_df.genres.apply(GenreList)

# %%
movies_df.genres.value_counts().to_frame()
# Out:
#                                                     genres
# [Drama]                                                370
# [Comedy]                                               282
# [Comedy, Drama]                                        188
# [Drama, Romance]                                       185
# [Comedy, Drama, Romance]                               182
# ...                                                    ...
# [Action, Adventure, Drama, History, Western]             1
# [Action, Adventure, Animation, Comedy, Family, ...       1
# [Adventure, Fantasy, Mystery, Thriller]                  1
# [Adventure, Comedy, Fantasy, Mystery]                    1
# [Comedy, Drama, Romance, TV Movie]                       1
#
# [638 rows x 1 columns]

# %%
movies_df.keywords = movies_df.keywords.apply(GenreList)
movies_df.keywords.value_counts().to_frame()
# Out:
#                                                     keywords
# []                                                       412
# [independent film]                                        55
# [woman director]                                          42
# [duringcreditsstinger]                                    15
# [sport]                                                   13
# ...                                                      ...
# [freighter, fundraiser, parking garage]                    1
# [dea, drug cartel]                                         1
# [catholic church, investigation, mentor protégé...         1
# [aerial shot, broken neck, fbi agent, flare, mi...         1
# [camcorder, crush, dream girl, obsession]                  1
#
# [4222 rows x 1 columns]

# %%
movies_df.cast = movies_df.cast.apply(GenreList)
movies_df.cast.value_counts().to_frame()
# Out:
#                                                     cast
# []                                                    43
# [Alicia Vela-Bailey, Allan Henry, Anthony Ingru...     1
# [Christian Slater, Gary Oldman, Jeff Bridges, J...     1
# [D. L. Hughley, Eduardo Verástegui, Freddy Rodr...     1
# [Cara Seymour, David Zayas, Debra Monk, Gbenga ...     1
# ...                                                  ...
# [Ben Whitehead, Christopher Fairbank, Dicken As...     1
# [Alison Doody, Anthony Chinn, Bill Ackridge, Bo...     1
# ["Weird Al" Yankovic, Andre Rosey Brown, Ann B....     1
# [Anne Meara, Brenda Song, Crispin Glover, David...     1
# [Bill D'Elia, Brian Herzlinger, Corey Feldman, ...     1
#
# [4761 rows x 1 columns]

# %%
crew_lis = movies_df.crew[0]

# %%
def Job_find(crew_lis:str,Job:str)->str:
  for i in list(eval(crew_lis)):
    for key in i:
      if key == 'job' and i[key] == Job:
        return i['name']

# %%
movies_df['Director'] = ''
movies_df.Director = movies_df.crew.apply(lambda x: Job_find(x,'Director'))
movies_df.Director.value_counts().to_frame()
# Out:
#                    Director
# Steven Spielberg         27
# Woody Allen              21
# Martin Scorsese          20
# Clint Eastwood           20
# Ridley Scott             16
# ...                     ...
# Timothy Bjorklund         1
# Marcus Dunstan            1
# Lorene Scafaria           1
# Jeff Lowell               1
# Brian Herzlinger          1
#
# [2349 rows x 1 columns]

# %%
movies_df.overview.fillna('',inplace=True)
movies_df.overview=movies_df.overview.apply(lambda x:x.split())

# %%
# Out:
# 0       [In, the, 22nd, century,, a, paraplegic, Marin...
# 1       [Captain, Barbossa,, long, believed, to, be, d...
# 2       [A, cryptic, message, from, Bond’s, past, send...
# 3       [Following, the, death, of, District, Attorney...
# 4       [John, Carter, is, a, war-weary,, former, mili...
#                               ...
# 4798    [El, Mariachi, just, wants, to, play, his, gui...
# 4799    [A, newlywed, couple's, honeymoon, is, upended...
# 4800    ["Signed,, Sealed,, Delivered", introduces, a,...
# 4801    [When, ambitious, New, York, attorney, Sam, is...
# 4802    [Ever, since, the, second, grade, when, he, fi...
# Name: overview, Length: 4803, dtype: object
